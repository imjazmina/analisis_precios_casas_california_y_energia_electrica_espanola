# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("camnugent/california-housing-prices")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Jazmin\.cache\kagglehub\datasets\camnugent\california-housing-prices\versions\1

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("manualrg/spanish-electricity-market-demand-gen-price")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (0.4.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/manualrg/spanish-electricity-market-demand-gen-price?dataset_version_number=1...
# 100%|██████████| 285k/285k [00:00<00:00, 515kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Jazmin\.cache\kagglehub\datasets\manualrg\spanish-electricity-market-demand-gen-price\versions\1
